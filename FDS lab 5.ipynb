# %%
# !pip install tabula-py

import pandas as pd
import numpy as np
from scipy import stats as st
import scipy as sp


from google.colab import files
uploaded = files.upload()
import tabula
tabula.convert_into("Car Dataset.pdf", "Car Dataset.csv", output_format="csv", pages='all')
Data = pd.read_csv('Car Dataset.csv')
Data.drop(['CO2'],axis=1,inplace=True)
Data.rename({'Unnamed: 4':'CO2'},axis=1,inplace=True)

print(Data)
# Out:
# ...
#      <input type="file" id="files-3b16c77b-9bf7-4ad7-8034-1e870dad11fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b16c77b-9bf7-4ad7-8034-1e870dad11fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Stem graph

# %%
plt.stem(Data.Volume, Data.CO2)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Violine graph

# %%
import seaborn as sb

# %%
sb.violinplot(x='CO2',y='Volume',data=Data)
# Out:
# <Axes: xlabel='CO2', ylabel='Volume'>

# %%
sb.kdeplot(x = Data.CO2,fill='True')
# Out:
# <Axes: xlabel='CO2', ylabel='Density'>

# %%
sb.kdeplot(y = Data.Volume,fill='True')
# Out:
# <Axes: xlabel='Density', ylabel='Volume'>

# %%
x = Data.CO2
y = Data.Volume
sb.kdeplot(x='CO2',y='Volume', data=Data, fill=True)
# Out:
# <Axes: xlabel='CO2', ylabel='Volume'>

# %%
sb.regplot(x ='CO2', y ='Weight', data = Data)
# Out:
# <Axes: xlabel='CO2', ylabel='Weight'>
